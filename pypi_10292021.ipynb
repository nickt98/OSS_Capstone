# %%
#import libraries
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import time

# %% [markdown]
# There were a few APIs at the time of this notebook.
# Directly at pypi
# - https://wiki.python.org/moin/PyPIJSON
# - In the format https://pypi.python.org/pypi/<package_name>/json
#
# There is also https://pypistats.org/
#  - They ask that any large amount of API access go through Google Big Query
#
# Google Big Query
# - https://cloud.google.com/docs/authentication/getting-started
# - https://bigquery.cloud.google.com/table/the-psf:pypi.downloads

# %%
# May need to install these
#!pip install jk_pypiorgapi
#!pip install pyarrow

# %% [markdown]
# ## Authenticate and Construct Google Big Query Object

# %%
from google.cloud import bigquery
from google.oauth2 import service_account

# TODO(developer): Set key_path to the path to the service account key
#                  file.
key_path = "msdscapstone-db80de77b383.json"

credentials = service_account.Credentials.from_service_account_file(
    key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"],
)

client = bigquery.Client(credentials=credentials, project=credentials.project_id,)

# %% [markdown]
# ## Pypi Distribution Metadata Statistics and Data Download Queries

# %%
# Find schema for thsi table here: https://docs.google.com/document/d/1mtZD2iw0TmzfNepCABdMCkhk-jwLgdgFP9awSkccwaw/edit#

# %%
#This query gives number of rows in the distribution meta data table
query = """
    SELECT Count(*) 
    FROM `the-psf.pypi.distribution_metadata`
    WHERE license is NOT NULL
"""
query_job = client.query(query)  # Make an API request.
results = query_job.result()  # Waits for job to complete.
#iterate through results object to fetch rows.
for row in results:
    row = str(row)[5:].split(',')[0]
    print(f"Row count with licenses = {row}")
# Out:
# Row count with licenses = 4223089

# %%
#This query gives number of rows in the distribution meta data table which have licenses and have the home_page in github
query = """
    SELECT count(*)
    FROM `the-psf.pypi.distribution_metadata`
    WHERE (lower(license)!='none' or lower(license)!='no license' or license is NOT NULL) and
    version NOT LIKE '%%dev%%' and home_page LIKE '%%github%%    
"""
query_job = client.query(query)  # Make an API request.
print("The query data:")
results = query_job.result()  # Waits for job to complete.
#iterate through results object to fetch rows.
for row in results:
    row = str(row)[5:].split(',')[0]
    print(f"rows with license and with home page in github = {row}")
# Out:
# The query data:
# rows with license and with home page in github = 2861425

# %%
#For understanding more on handling Array String data types in bigquery: 
# https://cloud.google.com/bigquery/docs/reference/standard-sql/array_functions#array_length
#https://cloud.google.com/spanner/docs/array_functions

# %%
#This query gives number of rows in the distribution meta data table which have licenses and have the home_page in github and also have dependencies
query = """
    SELECT name, version, author, author_email, license, home_page, ARRAY_TO_STRING(requires_dist,',') as dependency
    FROM `the-psf.pypi.distribution_metadata`
    WHERE (lower(license) <> 'none' or lower(license) <> 'no license' or license is NOT NULL) and
    version NOT LIKE '%%dev%%' and home_page LIKE '%%github%%' and ARRAY_LENGTH(requires_dist)<>0    
"""
query_job = client.query(query)  # Make an API request.
results = query_job.result()  # Waits for job to complete.

# %%
# %%time
dataframe_meta_with_license_dependecies = results.to_dataframe(
    # Optionally, explicitly request to use the BigQuery Storage API. As of
    # google-cloud-bigquery version 1.26.0 and above, the BigQuery Storage
    # API is used by default.
    #create_bqstorage_client=True,
)

# %%
dataframe_meta_with_license_dependecies
# Out:
#               name            version  \
# 0            vmush              0.0.1
# 1           pymush              0.0.1
# 2        ephemeris             0.10.7
# 3        deephyper              0.2.5
# 4             kcli  99.0.202105302125
# ...            ...                ...
# 1257990   fastbook             0.0.15
# 1257991     fastai              2.1.8
# 1257992  kinstabot            0.117.3
# 1257993  kinstabot            0.117.2
# 1257994  kinstabot            0.117.1
#
#                                                     author  \
# 0                                                   Volund
# 1                                                   Volund
# 2                             Galaxy Project and Community
# 3        Prasanna Balaprakash <pbalapra@anl.gov>, Romai...
# 4                                          Karim Boumedhel
# ...                                                    ...
# 1257990                   Jeremy Howard and Sylvain Gugger
# 1257991    Jeremy Howard, Sylvain Gugger, and contributors
# 1257992                   Daniil Okhlopkov, Evgeny Kemerov
# 1257993                   Daniil Okhlopkov, Evgeny Kemerov
# 1257994                   Daniil Okhlopkov, Evgeny Kemerov
#
#                                         author_email  \
# 0                                               None
# 1                                               None
# 2                                jmchilton@gmail.com
# 3                                               None
# 4                           karimboumedhel@gmail.com
# ...                                              ...
# 1257990                                 info@fast.ai
# 1257991                                 info@fast.ai
# 1257992  danokhlopkov@gmail.com, eskemerov@gmail.com
# 1257993  danokhlopkov@gmail.com, eskemerov@gmail.com
# 1257994  danokhlopkov@gmail.com, eskemerov@gmail.com
#
#                              license  \
# 0                                ???
# 1                                ???
# 2                                AFL
# 3                                ANL
# 4                                ASL
# ...                              ...
# 1257990  Apache Software License 2.0
# 1257991  Apache Software License 2.0
# 1257992  Apache Software License 2.0
# 1257993  Apache Software License 2.0
# 1257994  Apache Software License 2.0
#
#                                              home_page  \
# 0                  https://github.com/volundmush/vmush
# 1                 https://github.com/volundmush/pymush
# 2           https://github.com/galaxyproject/ephemeris
# 3               https://github.com/deephyper/deephyper
# 4                        http://github.com/karmab/kcli
# ...                                                ...
# 1257990             https://github.com/fastai/fastbook
# 1257991  https://github.com/fastai/fastai/tree/master/
# 1257992       https://github.com/instagrambot/instabot
# 1257993       https://github.com/instagrambot/instabot
# 1257994       https://github.com/instagrambot/instabot
#
#                                                 dependency
# 0                                    pymush,django (>=3.2)
# 1        athanor,mudstring,rich,passlib,argon2-cffi,pyt...
# 2        six (>=1.9.0),PyYAML,bioblend (>=0.10.0),Jinja...
# 3        tensorflow (>=2.0.0),tensorflow-probability,nu...
# 4        argcomplete,netaddr,PyYAML,prettytable,jinja2,...
# ...                                                    ...
# 1257990  pip,packaging,fastai (>=2.1),ipywidgets,nbdev ...
# 1257991  pip,packaging,fastcore (>=1.3.8),torchvision (...
# 1257992  certifi (>=2019.11.28),chardet (>=3.0.4),futur...
# 1257993  certifi (>=2019.11.28),chardet (>=3.0.4),futur...
# 1257994  certifi (>=2019.11.28),chardet (>=3.0.4),futur...
#
# [1257995 rows x 7 columns]

# %%
#some stats
print('All=',dataframe_meta_with_license_dependecies.shape)
print('with licenses=',dataframe_meta_with_license_dependecies[dataframe_meta_with_license_dependecies.license.isna()==False].shape)
print('with authors=',dataframe_meta_with_license_dependecies[dataframe_meta_with_license_dependecies.author.isna()==False].shape)
print('with author_email=',dataframe_meta_with_license_dependecies[dataframe_meta_with_license_dependecies.author_email.isna()==False].shape)
# Out:
# All= (1257995, 7)
# with licenses= (1257995, 7)
# with authors= (1212457, 7)
# with author_email= (1077321, 7)

# %%
#changing all text to lower for easy querying
df_pypi_meta_with_license = dataframe_meta_with_license_dependecies.apply(lambda x: x.astype(str).str.lower())

# %%
#look at sample data
df_pypi_meta_with_license.sample(10)
# Out:
#                            name           version               author  \
# 427879                pymartini             0.3.0          kyle barron
# 512348      beets-vtalbumartist             1.0.0       rafael parente
# 767051                   e-data             0.1.7                  vmg
# 828160                 credsafe            0.0.24              f̣ộx̣ệ6
# 1051487            sphinx-click             1.4.1     stephen finucane
# 142731                   pyibex           1.8.0b1    benoit desrochers
# 305672                     ipwb  0.2021.5.20.1444            mat kelly
# 957991     aws-cdk.aws-amazonmq            1.64.0  amazon web services
# 903812   aws-cdk.aws-codedeploy           1.106.0  amazon web services
# 436570                  proplot             0.2.1           luke davis
#
#                   author_email      license  \
# 427879   kylebarron2@gmail.com          mit
# 512348   rafaelp.dev@gmail.com          mit
# 767051      vmayorg@outlook.es        gplv3
# 828160    foxe6@protonmail.com     agpl-3.0
# 1051487      stephen@that.guru  mit license
# 142731     ben.ensta@gmail.com      lgplv3+
# 305672         me@matkelly.com          mit
# 957991                    none   apache-2.0
# 903812                    none   apache-2.0
# 436570       lukelbd@gmail.com          mit
#
#                                                  home_page  \
# 427879             https://github.com/kylebarron/pymartini
# 512348   https://github.com/rafaelp-dev/beets-vtalbumar...
# 767051             https://github.com/uvejota/python-edata
# 828160              https://github.com/foxe6-temp/credsafe
# 1051487         https://github.com/stephenfin/sphinx-click
# 142731                  https://github.com/benensta/pyibex
# 305672                     https://github.com/oduwsdl/ipwb
# 957991                      https://github.com/aws/aws-cdk
# 903812                      https://github.com/aws/aws-cdk
# 436570                   https://lukelbd.github.io/proplot
#
#                                                 dependency
# 427879   numpy,pytest ; extra == 'test',pytest-benchmar...
# 512348                                               beets
# 767051           bs4,pandas,pyjwt,python-dateutil,requests
# 828160               easyrsa (>=0.0.1),omnitools (>=0.0.1)
# 1051487                    pbr (>=2.0),sphinx (<2.0,>=1.5)
# 142731                                               vibes
# 305672   warcio (>=1.5.3),ipfshttpclient (>=0.6.0),flas...
# 957991   aws-cdk.core (==1.64.0),constructs (<4.0.0,>=3...
# 903812   aws-cdk.aws-autoscaling (==1.106.0),aws-cdk.aw...
# 436570                                     matplotlib,lxml

# %%
#save to csv
df_pypi_meta_with_license.to_csv('pypi_meta_with_license_dependecies.csv')

# %% [markdown]
# ## Explode the requires_dist field into sperate rows

# %%
#save data in a temp dataframe
temp_df = df_pypi_meta_with_license.sample(10)

# %%
# %%time
#check results
df = temp_df.join(temp_df['dependency'].str.split(',', expand=True))
# Out:
#                       name version                 author  \
# 427919         shipane-sdk   1.4.3                 sinall
# 788385               pfifo   1.1.5           kotone itaya
# 664789        genice2-cage     2.1     masakazu matsumoto
# 570444       csr2transmart  0.0.18              gijs kant
# 483554            cdrouter  0.4.27                qa cafe
# 544792        azure-cli-vm  2.2.13  microsoft corporation
# 345381   markdown-aafigure   0.1.3         manuel barkhau
# 298538             aiomisc  14.1.0           dmitry orlov
# 1074305     mypy-boto3-fis  1.19.5         vlad emelianov
# 29673                 fsds  0.2.19           james irving
#
#                         author_email                        license  \
# 427919             gaoruinan@163.com                            mit
# 788385         kotone@sfc.keio.ac.jp                         apache
# 664789             vitroid@gmail.com                            mit
# 570444               gijs@thehyve.nl                            mit
# 483554            support@qacafe.com                            mit
# 544792         azpycli@microsoft.com                            mit
# 345381            mbarkhau@gmail.com                            mit
# 298538                me@mosquito.su                            mit
# 1074305  vlad.emelianov.nz@gmail.com                    mit license
# 29673     james.irving.phd@gmail.com  gnu general public license v3
#
#                                                home_page  \
# 427919      https://github.com/sinall/shipane-python-sdk
# 788385                    https://github.com/ktnyt/pfifo
# 664789           https://github.com/vitroid/genice-cage/
# 570444   https://github.com/thehyve/python_csr2transmart
# 483554             https://github.com/qacafe/cdrouter.py
# 544792                https://github.com/azure/azure-cli
# 345381     https://github.com/mbarkhau/markdown-aafigure
# 298538               https://github.com/mosquito/aiomisc
# 1074305      https://github.com/vemel/mypy_boto3_builder
# 29673                 https://github.com/jirvingphd/fsds
#
#                                                 dependency  \
# 427919   apscheduler,bs4,cssselect,html5lib,lxml,pandas...
# 788385                                    pybind11 (>=2.2)
# 664789   cycless,attrdict,networkx,numpy,yaplotlib (>=0...
# 570444   click (<8.0,>=7.0),transmart-loader (<1.4.0,>=...
# 483554       future,marshmallow,requests,requests-toolbelt
# 544792   azure-mgmt-msi (==0.2.0),azure-mgmt-authorizat...
# 345381                                   markdown,aafigure
# 298538   colorlog,async-generator ; python_version < "3...
# 1074305         typing-extensions ; python_version < "3.9"
# 29673    numpy (>=1.18),missingno,pandas (>1.0.0),seabo...
#
#                                                   0  \
# 427919                                  apscheduler
# 788385                             pybind11 (>=2.2)
# 664789                                      cycless
# 570444                                  click (<8.0
# 483554                                       future
# 544792                     azure-mgmt-msi (==0.2.0)
# 345381                                     markdown
# 298538                                     colorlog
# 1074305  typing-extensions ; python_version < "3.9"
# 29673                                numpy (>=1.18)
#
#                                                 1  \
# 427919                                        bs4
# 788385                                       None
# 664789                                   attrdict
# 570444                                     >=7.0)
# 483554                                marshmallow
# 544792        azure-mgmt-authorization (==0.50.0)
# 345381                                   aafigure
# 298538   async-generator ; python_version < "3.7"
# 1074305                                      None
# 29673                                   missingno
#
#                                     2  ...  \
# 427919                      cssselect  ...
# 788385                           None  ...
# 664789                       networkx  ...
# 570444       transmart-loader (<1.4.0  ...
# 483554                       requests  ...
# 544792   azure-mgmt-compute (==4.4.0)  ...
# 345381                           None  ...
# 298538   aiohttp ; extra == 'aiohttp'  ...
# 1074305                          None  ...
# 29673                 pandas (>1.0.0)  ...
#
#                                                 20  \
# 427919                                        None
# 788385                                        None
# 664789                                        None
# 570444                                        None
# 483554                                        None
# 544792                                        None
# 345381                                        None
# 298538   pytest-cov (~=2.5.1) ; extra == 'develop'
# 1074305                                       None
# 29673                                         None
#
#                                                       21  \
# 427919                                              None
# 788385                                              None
# 664789                                              None
# 570444                                              None
# 483554                                              None
# 544792                                              None
# 345381                                              None
# 298538   pytest-freezegun (~=0.4.2) ; extra == 'develop'
# 1074305                                             None
# 29673                                               None
#
#                                             22  \
# 427919                                    None
# 788385                                    None
# 664789                                    None
# 570444                                    None
# 483554                                    None
# 544792                                    None
# 345381                                    None
# 298538   sphinx (>=3.5.1) ; extra == 'develop'
# 1074305                                   None
# 29673                                     None
#
#                                             23  \
# 427919                                    None
# 788385                                    None
# 664789                                    None
# 570444                                    None
# 483554                                    None
# 544792                                    None
# 345381                                    None
# 298538   sphinx-autobuild ; extra == 'develop'
# 1074305                                   None
# 29673                                     None
#
#                                        24  \
# 427919                               None
# 788385                               None
# 664789                               None
# 570444                               None
# 483554                               None
# 544792                               None
# 345381                               None
# 298538   sphinx-intl ; extra == 'develop'
# 1074305                              None
# 29673                                None
#
#                                              25  \
# 427919                                     None
# 788385                                     None
# 664789                                     None
# 570444                                     None
# 483554                                     None
# 544792                                     None
# 345381                                     None
# 298538   timeout-decorator ; extra == 'develop'
# 1074305                                    None
# 29673                                      None
#
#                                        26                                27  \
# 427919                               None                              None
# 788385                               None                              None
# 664789                               None                              None
# 570444                               None                              None
# 483554                               None                              None
# 544792                               None                              None
# 345381                               None                              None
# 298538   tox (>=2.4) ; extra == 'develop'  raven-aiohttp ; extra == 'raven'
# 1074305                              None                              None
# 29673                                None                              None
#
#                  28                           29
# 427919         None                         None
# 788385         None                         None
# 664789         None                         None
# 570444         None                         None
# 483554         None                         None
# 544792         None                         None
# 345381         None                         None
# 298538   uvloop (<1  >=0.14) ; extra == 'uvloop'
# 1074305        None                         None
# 29673          None                         None
#
# [10 rows x 37 columns]

# %%
#save to csv
df.to_csv('pypi_name_version_author_license_homepg.csv')

# %% [markdown]
# # Sample query to pull Downloads data

# %%
#https://medium.com/google-cloud/how-to-work-with-array-and-structs-in-bigquery-9c0a2ea584a6

# %%
# %%time
#This query pulls data from downloads table

query_downloads = """
    SELECT  country_code, STRUCT(file.project as name), STRUCT(file.version as version)
    FROM `bigquery-public-data.pypi.file_downloads`
    WHERE
    DATE(timestamp)
    BETWEEN DATE_TRUNC(DATE_SUB(CURRENT_DATE(), INTERVAL 1 DAY), DAY)
    AND CURRENT_DATE()
    --LIMIT 5 --use for checking sample data before running whole query
"""
query_job_dl = client.query(query_downloads)  # Make an API request.
results_downloads = query_job_dl.result()  # Waits for job to complete.
# Out:
# CPU times: user 11.6 ms, sys: 1.97 ms, total: 13.6 ms
# Wall time: 16.9 s

# %%
# %%time
#This query pulls data from downloads table

query_downloads = """
    SELECT  country_code, ANY_VALUE(STRUCT(file.project)) as name, ANY_VALUE(STRUCT(file.version)) as version,
    Count(STRUCT(file.project)) as num_downloads 
    FROM `bigquery-public-data.pypi.file_downloads`
    WHERE
    DATE(timestamp)
    BETWEEN DATE_TRUNC(DATE_SUB(CURRENT_DATE(), INTERVAL 30 DAY), 30DAY)
    AND CURRENT_DATE()
    GROUP BY country_code, file.project ,file.version
    ORDER BY Count(STRUCT(file.project)) DESC
    --LIMIT 5 --use for checking sample data before running whole query
"""
query_job_dl = client.query(query_downloads)  # Make an API request.
results_downloads = query_job_dl.result()  # Waits for job to complete.
# Out:
# CPU times: user 6.94 ms, sys: 4.92 ms, total: 11.9 ms
# Wall time: 24.1 s

# %%
# %%time
dataframe_downloads = results_downloads.to_dataframe(
    # Optionally, explicitly request to use the BigQuery Storage API. As of
    # google-cloud-bigquery version 1.26.0 and above, the BigQuery Storage
    # API is used by default.
    #create_bqstorage_client=True,
)
# Out:
# CPU times: user 4min 2s, sys: 3.58 s, total: 4min 6s
# Wall time: 13min 30s

# %%
# %%time
dataframe_downloads#.shape
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.77 µs
#          country_code                                               name  \
# 0                  CA                                 {'project': 'six'}
# 1                  CA                     {'project': 'python-dateutil'}
# 2                  CA                             {'project': 'urllib3'}
# 3                  CA                            {'project': 'jmespath'}
# 4                  CA                          {'project': 's3transfer'}
# ...               ...                                                ...
# 12405430           NL                  {'project': 'mosaik-demo-semver'}
# 12405431           KG                                {'project': 'moto'}
# 12405432           NL   {'project': 'odoo10-addon-connector-prestashop'}
# 12405433           NL  {'project': 'odoo14-addon-fieldservice-equipme...
# 12405434           CA                  {'project': 'mypy-boto3-acm-pca'}
#
#                                        version  num_downloads
# 0                        {'version': '1.16.0'}        9625437
# 1                         {'version': '2.8.2'}        9609601
# 2                        {'version': '1.26.7'}        9602770
# 3                        {'version': '0.10.0'}        9587288
# 4                         {'version': '0.5.0'}        9554432
# ...                                        ...            ...
# 12405430  {'version': '0.1.0rc20200908125020'}              1
# 12405431                 {'version': '2.2.11'}              1
# 12405432     {'version': '10.0.1.1.0.99.dev2'}              1
# 12405433             {'version': '14.0.1.1.0'}              1
# 12405434              {'version': '1.12.30.0'}              1
#
# [12405435 rows x 4 columns]

# %%
dataframe_downloads.to_csv('pypi_downloads_DAY_1028201.csv')
