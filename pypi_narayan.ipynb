# %%
import os
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# There were a few APIs at the time of this notebook.
# Directly at pypi
# - https://wiki.python.org/moin/PyPIJSON
# - In the format https://pypi.python.org/pypi/<package_name>/json
#
# There is also https://pypistats.org/
#  - They ask that any large amount of API access go through Google Big Query
#
# Google Big Query
# - https://cloud.google.com/docs/authentication/getting-started
# - https://bigquery.cloud.google.com/table/the-psf:pypi.downloads

# %%
# May need to install these
#!pip install jk_pypiorgapi
#!pip install pyarrow

# %% [markdown]
# ## Authenticate and Construct Google Big Query Object

# %%
from google.cloud import bigquery
from google.oauth2 import service_account

# TODO(developer): Set key_path to the path to the service account key
#                  file.
key_path = "msdscapstone-db80de77b383.json"

credentials = service_account.Credentials.from_service_account_file(
    key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"],
)

client = bigquery.Client(credentials=credentials, project=credentials.project_id,)

# Construct a BigQuery client object.
#client = bigquery.Client()

query = """
    SELECT COUNT(*) AS num_downloads
    FROM `bigquery-public-data.pypi.file_downloads`
    WHERE file.project = 'pytest'
    -- Only query the last 30 days of history
    AND DATE(timestamp)
    BETWEEN DATE_SUB(CURRENT_DATE(), INTERVAL 30 DAY)
    AND CURRENT_DATE()
"""
query_job = client.query(query)  # Make an API request.

print("The query data:")
results = query_job.result()  # Waits for job to complete.
for row in results:
    print("{} downloads".format(row.num_downloads))
# Out:
# The query data:
# 30963935 downloads

# %%
from google.cloud import bigquery
import pyarrow

bqclient = bigquery.Client(credentials=credentials, project=credentials.project_id)
''' 
The below query gets name, version, author,author_email,license,package_type, filename for pypi packages
'''
# Download a table.
table = bigquery.TableReference.from_string(
    "the-psf.pypi.distribution_metadata"
)
rows = bqclient.list_rows(
    table,
    selected_fields=[
        bigquery.SchemaField("name", "STRING"),
        bigquery.SchemaField("version", "STRING"),
        bigquery.SchemaField("author", "STRING"),
        bigquery.SchemaField("author_email", "STRING"),
        bigquery.SchemaField("license", "STRING"),
        #bigquery.SchemaField("requires", "STRING"),
        #bigquery.SchemaField("requires_dist", "STRING"),
        bigquery.SchemaField("packagetype", "STRING"),
        bigquery.SchemaField("filename", "STRING")
    ],
)
dataframe = rows.to_dataframe(
    # Optionally, explicitly request to use the BigQuery Storage API. As of
    # google-cloud-bigquery version 1.26.0 and above, the BigQuery Storage
    # API is used by default.
    #create_bqstorage_client=True,
)

# %%
#some stats
print('All=',dataframe.shape)
print('with licenses=',dataframe[dataframe.license.isna()==False].shape)
print('with authors=',dataframe[dataframe.author.isna()==False].shape)
print('with author_email=',dataframe[dataframe.author_email.isna()==False].shape)
# Out:
# All= (5506499, 7)
# with licenses= (4121423, 7)
# with authors= (5258826, 7)
# with author_email= (4866969, 7)

# %%
#changing all text to lower for easy querying
df_pypi_meta = dataframe.apply(lambda x: x.astype(str).str.lower())

# %%
#data cleaning, last 65 rows do not seem to parse properly..dropping them
df_pypi_meta = df_pypi_meta.loc[0:5506433]

# %%
#save the file
df_pypi_meta.to_csv('pypi_author_license.csv')

# %%
df_pypi_meta[df_pypi_meta.name=='pandas']
# Out:
#            name    version                       author  \
# 13017    pandas     0.24.0                         none
# 13075    pandas  0.25.0rc0                         none
# 13103    pandas   1.0.0rc0                         none
# 13104    pandas   1.0.0rc0                         none
# 27049    pandas     0.19.1  the pydata development team
# ...         ...        ...                          ...
# 5457617  pandas      1.3.3  the pandas development team
# 5457618  pandas      1.3.3  the pandas development team
# 5457619  pandas      1.3.3  the pandas development team
# 5457620  pandas      1.3.3  the pandas development team
# 5457621  pandas      1.3.3  the pandas development team
#
#                     author_email       license  \
# 13017                       none           bsd
# 13075                       none           bsd
# 13103                       none           bsd
# 13104                       none           bsd
# 27049    pydata@googlegroups.com           bsd
# ...                          ...           ...
# 5457617    pandas-dev@python.org  bsd-3-clause
# 5457618    pandas-dev@python.org  bsd-3-clause
# 5457619    pandas-dev@python.org  bsd-3-clause
# 5457620    pandas-dev@python.org  bsd-3-clause
# 5457621    pandas-dev@python.org  bsd-3-clause
#
#                                                packagetype     filename
# 13017       pandas-0.24.0-cp35-cp35m-manylinux1_x86_64.whl  bdist_wheel
# 13075    pandas-0.25.0rc0-cp37-cp37m-manylinux1_x86_64.whl  bdist_wheel
# 13103              pandas-1.0.0rc0-cp38-cp38-win_amd64.whl  bdist_wheel
# 13104              pandas-1.0.0rc0-cp38-cp38-win_amd64.whl  bdist_wheel
# 27049         pandas-0.19.1-cp35-cp35m-manylinux1_i686.whl  bdist_wheel
# ...                                                    ...          ...
# 5457617  pandas-1.3.3-cp310-cp310-manylinux_2_17_x86_64...  bdist_wheel
# 5457618     pandas-1.3.3-cp37-cp37m-macosx_10_9_x86_64.whl  bdist_wheel
# 5457619  pandas-1.3.3-cp37-cp37m-manylinux_2_17_aarch64...  bdist_wheel
# 5457620  pandas-1.3.3-cp39-cp39-manylinux_2_5_i686.many...  bdist_wheel
# 5457621  pandas-1.3.3-cp39-cp39-manylinux_2_17_x86_64.m...  bdist_wheel
#
# [1432 rows x 7 columns]

# %% [markdown]
# ## Pull contributors from github

# %%
#https://towardsdatascience.com/all-the-things-you-can-do-with-github-api-and-python-f01790fca131

# %%
#goto developer settings on your profile settings and generate this
token = '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'

from github import Github

# First create a Github instance:

# using an access token
g = Github(token)

# Github Enterprise with custom hostname
repo = g.get_repo("pandas-dev/pandas")
contrib = repo.get_contributors()
contrib

# %%
contrib_list = []
for con in contrib:
	contrib_list.append(con)

# %%
contrib_list
# Out:
# [NamedUser(login="jreback"),
#  NamedUser(login="jbrockmendel"),
#  NamedUser(login="wesm"),
#  NamedUser(login="jorisvandenbossche"),
#  NamedUser(login="TomAugspurger"),
#  NamedUser(login="cpcloud"),
#  NamedUser(login="simonjayhawkins"),
#  NamedUser(login="gfyoung"),
#  NamedUser(login="mroeschke"),
#  NamedUser(login="sinhrks"),
#  NamedUser(login="adamklein"),
#  NamedUser(login="topper-123"),
#  NamedUser(login="jtratner"),
#  NamedUser(login="changhiskhan"),
#  NamedUser(login="WillAyd"),
#  NamedUser(login="phofl"),
#  NamedUser(login="ShaharNaveh"),
#  NamedUser(login="datapythonista"),
#  NamedUser(login="jschendel"),
#  NamedUser(login="hayd"),
#  NamedUser(login="dsaxton"),
#  NamedUser(login="rhshadrach"),
#  NamedUser(login="attack68"),
#  NamedUser(login="MarcoGorelli"),
#  NamedUser(login="fangchenli"),
#  NamedUser(login="mzeitlin11"),
#  NamedUser(login="orbitfold"),
#  NamedUser(login="alimcmaster1"),
#  NamedUser(login="toobaz"),
#  NamedUser(login="jseabold"),
#  NamedUser(login="charlesdong1991"),
#  NamedUser(login="chris-b1"),
#  NamedUser(login="h-vetinari"),
#  NamedUser(login="shoyer"),
#  NamedUser(login="lodagro"),
#  NamedUser(login="arw2019"),
#  NamedUser(login="ivanovmg"),
#  NamedUser(login="twoertwein"),
#  NamedUser(login="bashtage"),
#  NamedUser(login="SaturnFromTitan"),
#  NamedUser(login="lithomas1"),
#  NamedUser(login="mortada"),
#  NamedUser(login="Dr-Irv"),
#  NamedUser(login="qwhelan"),
#  NamedUser(login="takluyver"),
#  NamedUser(login="behzadnouri"),
#  NamedUser(login="kawochen"),
#  NamedUser(login="Komnomnomnom"),
#  NamedUser(login="reidy-p"),
#  NamedUser(login="bwignall"),
#  NamedUser(login="avinashpancham"),
#  NamedUser(login="jankatins"),
#  NamedUser(login="makbigc"),
#  NamedUser(login="dsm054"),
#  NamedUser(login="gliptak"),
#  NamedUser(login="rockg"),
#  NamedUser(login="evanpw"),
#  NamedUser(login="yarikoptic"),
#  NamedUser(login="immerrr"),
#  NamedUser(login="davidastephens"),
#  NamedUser(login="JustinZhengBC"),
#  NamedUser(login="debnathshoham"),
#  NamedUser(login="stephenwlin"),
#  NamedUser(login="thoo"),
#  NamedUser(login="erfannariman"),
#  NamedUser(login="FHaase"),
#  NamedUser(login="danielballan"),
#  NamedUser(login="Licht-T"),
#  NamedUser(login="ganevgv"),
#  NamedUser(login="minggli"),
#  NamedUser(login="moink"),
#  NamedUser(login="realead"),
#  NamedUser(login="ryankarlos"),
#  NamedUser(login="Moisan"),
#  NamedUser(login="lexual"),
#  NamedUser(login="partev"),
#  NamedUser(login="aflaxman"),
#  NamedUser(login="danbirken"),
#  NamedUser(login="AlexKirko"),
#  NamedUser(login="farhanreynaldo"),
#  NamedUser(login="kshedden"),
#  NamedUser(login="unutbu"),
#  NamedUser(login="afeld"),
#  NamedUser(login="xhochy"),
#  NamedUser(login="saurav-chakravorty"),
#  NamedUser(login="fujiaxiang"),
#  NamedUser(login="roberthdevries"),
#  NamedUser(login="onesandzeroes"),
#  NamedUser(login="parthea"),
#  NamedUser(login="snth"),
#  NamedUser(login="github-actions[bot]"),
#  NamedUser(login="gwrome"),
#  NamedUser(login="ihsansecer"),
#  NamedUser(login="sglyon"),
#  NamedUser(login="seth-p"),
#  NamedUser(login="discort"),
#  NamedUser(login="cancan101"),
#  NamedUser(login="toddrjen"),
#  NamedUser(login="vaibhavhrt"),
#  NamedUser(login="willpeppo"),
#  NamedUser(login="peterpanmj"),
#  NamedUser(login="neirbowj"),
#  NamedUser(login="llllllllll"),
#  NamedUser(login="max-sixty"),
#  NamedUser(login="kernc"),
#  NamedUser(login="Bharat123rox"),
#  NamedUser(login="lbeltrame"),
#  NamedUser(login="guyrt"),
#  NamedUser(login="invisibleroads"),
#  NamedUser(login="smithto1"),
#  NamedUser(login="tommyod"),
#  NamedUser(login="dhimmel"),
#  NamedUser(login="khughitt"),
#  NamedUser(login="nbonnotte"),
#  NamedUser(login="tswast"),
#  NamedUser(login="anmyachev"),
#  NamedUser(login="proost"),
#  NamedUser(login="terrytangyuan"),
#  NamedUser(login="GuessWhoSamFoo"),
#  NamedUser(login="GYHHAHA"),
#  NamedUser(login="funnycrab"),
#  NamedUser(login="AaronCritchley"),
#  NamedUser(login="alexander-ponomaroff"),
#  NamedUser(login="rosnfeld"),
#  NamedUser(login="Anjali2019"),
#  NamedUser(login="dalejung"),
#  NamedUser(login="erictleung"),
#  NamedUser(login="felixDulys"),
#  NamedUser(login="gdraps"),
#  NamedUser(login="jmcnamara"),
#  NamedUser(login="ArtificialQualia"),
#  NamedUser(login="blais"),
#  NamedUser(login="cbertinato"),
#  NamedUser(login="hongshaoyang"),
#  NamedUser(login="albertvillanova"),
#  NamedUser(login="charliec443"),
#  NamedUser(login="yui-knk"),
#  NamedUser(login="3vts"),
#  NamedUser(login="michaelaye"),
#  NamedUser(login="PKEuS"),
#  NamedUser(login="alefnula"),
#  NamedUser(login="cleconte987"),
#  NamedUser(login="glyg"),
#  NamedUser(login="adamjstewart"),
#  NamedUser(login="alysivji"),
#  NamedUser(login="ahawryluk"),
#  NamedUser(login="blbradley"),
#  NamedUser(login="HughKelley"),
#  NamedUser(login="jnothman"),
#  NamedUser(login="KalyanGokhale"),
#  NamedUser(login="miketkelly"),
#  NamedUser(login="OlivierLuG"),
#  NamedUser(login="RaisaDZ"),
#  NamedUser(login="varunkumar-dev"),
#  NamedUser(login="vnlitvinov"),
#  NamedUser(login="01-vyom"),
#  NamedUser(login="IHackPy"),
#  NamedUser(login="jnmclarty"),
#  NamedUser(login="nipunbatra"),
#  NamedUser(login="jsexauer"),
#  NamedUser(login="filmor"),
#  NamedUser(login="xcz011"),
#  NamedUser(login="Vlek"),
#  NamedUser(login="mdmueller"),
#  NamedUser(login="quangngd"),
#  NamedUser(login="r-toroxel"),
#  NamedUser(login="rushabh-v"),
#  NamedUser(login="sameshl"),
#  NamedUser(login="tkf"),
#  NamedUser(login="Winterflower"),
#  NamedUser(login="ftrihardjo"),
#  NamedUser(login="themien"),
#  NamedUser(login="hexgnu"),
#  NamedUser(login="pijucha"),
#  NamedUser(login="clham"),
#  NamedUser(login="mattip"),
#  NamedUser(login="CloseChoice"),
#  NamedUser(login="westurner"),
#  NamedUser(login="bjonen"),
#  NamedUser(login="dieterv77"),
#  NamedUser(login="Giftlin"),
#  NamedUser(login="aa1371"),
#  NamedUser(login="benjaminr"),
#  NamedUser(login="bburan-galenea"),
#  NamedUser(login="dbew"),
#  NamedUser(login="deepyaman"),
#  NamedUser(login="DriesSchaumont"),
#  NamedUser(login="Garrett-R"),
#  NamedUser(login="ginggs"),
#  NamedUser(login="HH-MWB"),
#  NamedUser(login="onshek"),
#  NamedUser(login="jeffcarey"),
#  NamedUser(login="mwoss"),
#  NamedUser(login="MicaelJarniac"),
#  NamedUser(login="mgmarino"),
#  NamedUser(login="nparley"),
#  NamedUser(login="nehalecky"),
#  NamedUser(login="shawnheide"),
#  NamedUser(login="stephen-hoover"),
#  NamedUser(login="lespaul"),
#  NamedUser(login="tacaswell"),
#  NamedUser(login="tolaa001"),
#  NamedUser(login="uds5501"),
#  NamedUser(login="vincentarelbundock"),
#  NamedUser(login="gepcel"),
#  NamedUser(login="ZhuBaohe"),
#  NamedUser(login="agraboso"),
#  NamedUser(login="ajcr"),
#  NamedUser(login="ischwabacher"),
#  NamedUser(login="krajatcl"),
#  NamedUser(login="mproszewska"),
#  NamedUser(login="rbenes"),
#  NamedUser(login="rebecca-palmer"),
#  NamedUser(login="smartvinnetou"),
#  NamedUser(login="timmie"),
#  NamedUser(login="tmnhat2001"),
#  NamedUser(login="almaleksia"),
#  NamedUser(login="oguzhanogreden"),
#  NamedUser(login="stijnvanhoey"),
#  NamedUser(login="metakermit"),
#  NamedUser(login="ma3da"),
#  NamedUser(login="adamobeng"),
#  NamedUser(login="addisonlynch"),
#  NamedUser(login="alanbato"),
#  NamedUser(login="alexprincel"),
#  NamedUser(login="asishm"),
#  NamedUser(login="chrisaycock"),
#  NamedUser(login="cbrnr"),
#  NamedUser(login="garaud"),
#  NamedUser(login="DataOmbudsman"),
#  NamedUser(login="proinsias"),
#  NamedUser(login="galuhsahid"),
#  NamedUser(login="math-and-data"),
#  NamedUser(login="janelle"),
#  NamedUser(login="jonmmease"),
#  NamedUser(login="mangecoeur"),
#  NamedUser(login="yehoshuadimarsky"),
#  NamedUser(login="elmq0022"),
#  NamedUser(login="msabramo"),
#  NamedUser(login="mwiebe"),
#  NamedUser(login="immaxchen"),
#  NamedUser(login="mdhsieh"),
#  NamedUser(login="nmusolino"),
#  NamedUser(login="OlehKSS"),
#  NamedUser(login="pv"),
#  NamedUser(login="nixphix"),
#  NamedUser(login="swyoon"),
#  NamedUser(login="sumanau7"),
#  NamedUser(login="sighingnow"),
#  NamedUser(login="dcreekp"),
#  NamedUser(login="tdpetrou"),
#  NamedUser(login="tomazberisa"),
#  NamedUser(login="troels"),
#  NamedUser(login="AncientRickles"),
#  NamedUser(login="scari"),
#  NamedUser(login="agijsberts"),
#  NamedUser(login="Donk23"),
#  NamedUser(login="fathomer"),
#  NamedUser(login="kylekeppler"),
#  NamedUser(login="pv8473h12"),
#  NamedUser(login="tshauck"),
#  NamedUser(login="matthewgilbert"),
#  NamedUser(login="ParfaitG"),
#  NamedUser(login="HubertKl"),
#  NamedUser(login="aileronajay"),
#  NamedUser(login="wuan"),
#  NamedUser(login="AnnaDaglis"),
#  NamedUser(login="amilbourne"),
#  NamedUser(login="arminv"),
#  NamedUser(login="databasedav"),
#  NamedUser(login="bthyreau"),
#  NamedUser(login="bobhaffner"),
#  NamedUser(login="brendam"),
#  NamedUser(login="bnaul"),
#  NamedUser(login="calvh"),
#  NamedUser(login="chalmerlowe"),
#  NamedUser(login="Cheukting"),
#  NamedUser(login="chrisjbillington"),
#  NamedUser(login="christopherzimmerman"),
#  NamedUser(login="chrish42"),
#  NamedUser(login="clarkfitzg"),
#  NamedUser(login="DaanVanHauwermeiren"),
#  NamedUser(login="dnmiller"),
#  NamedUser(login="wabu"),
#  NamedUser(login="dcanones"),
#  NamedUser(login="eoveson"),
#  NamedUser(login="frreiss"),
#  NamedUser(login="goyodiaz"),
#  NamedUser(login="gregglind"),
#  NamedUser(login="gcbeltramini"),
#  NamedUser(login="hsperr"),
#  NamedUser(login="jwkvam"),
#  NamedUser(login="jamesmyatt"),
#  NamedUser(login="JennaVergeynst"),
#  NamedUser(login="sjev"),
#  NamedUser(login="jiangyue12392"),
#  NamedUser(login="jcrist"),
#  NamedUser(login="karasinski"),
#  NamedUser(login="jzwinck"),
#  NamedUser(login="JonathanShrek"),
#  NamedUser(login="kevinastone"),
#  NamedUser(login="vadakattu"),
#  NamedUser(login="larsmans"),
#  NamedUser(login="LauraCollard"),
#  NamedUser(login="lorenzophys"),
#  NamedUser(login="lesteve"),
#  NamedUser(login="lucasrodes"),
#  NamedUser(login="mabelvj"),
#  NamedUser(login="MarianD"),
#  NamedUser(login="MaxVanDeursen"),
#  NamedUser(login="ChiefMilesEdgeworth"),
#  NamedUser(login="OXPHOS"),
#  NamedUser(login="ogrisel"),
#  NamedUser(login="dayoreke"),
#  NamedUser(login="ivanov"),
#  NamedUser(login="Qbiwan"),
#  NamedUser(login="cool-RR"),
#  NamedUser(login="rth"),
#  NamedUser(login="rouzazari"),
#  NamedUser(login="smc77"),
#  NamedUser(login="sofiane87"),
#  NamedUser(login="srinivasreddy"),
#  NamedUser(login="taljaards"),
#  NamedUser(login="graingert"),
#  NamedUser(login="VincentLa"),
#  NamedUser(login="vfilimonov"),
#  NamedUser(login="tvyomkesh"),
#  NamedUser(login="wholmgren"),
#  NamedUser(login="akosel"),
#  NamedUser(login="cel4"),
#  NamedUser(login="hasan-yaman"),
#  NamedUser(login="junjunjunk"),
#  NamedUser(login="kotamatsuoka"),
#  NamedUser(login="luzpaz"),
#  NamedUser(login="nrebena"),
#  NamedUser(login="saehuihwang"),
#  NamedUser(login="scls19fr"),
#  NamedUser(login="taytzehao"),
#  NamedUser(login="vangorade"),
#  NamedUser(login="waitingkuo"),
#  NamedUser(login="wcwagner"),
#  NamedUser(login="cmazzullo"),
#  NamedUser(login="watercrossing"),
#  NamedUser(login="jgehrcke"),
#  NamedUser(login="spacesphere"),
#  NamedUser(login="AbhijeetKrishnan"),
#  NamedUser(login="adamgreenhall"),
#  NamedUser(login="adamhooper"),
#  NamedUser(login="evectant"),
#  NamedUser(login="alexhlim"),
#  NamedUser(login="ahcub"),
#  NamedUser(login="alfonsomhc"),
#  NamedUser(login="AlpAribal"),
#  NamedUser(login="winklerand"),
#  NamedUser(login="Scorpil"),
#  NamedUser(login="aevri"),
#  NamedUser(login="anirudnits"),
#  NamedUser(login="anjsudh"),
#  NamedUser(login="aisipos"),
#  NamedUser(login="artemyk"),
#  NamedUser(login="crayxt"),
#  NamedUser(login="palewire"),
#  NamedUser(login="BenjaminLiuPenrose"),
#  NamedUser(login="bhavaniravi"),
#  NamedUser(login="another-green"),
#  NamedUser(login="HawkinsBA"),
#  NamedUser(login="BranYang"),
#  NamedUser(login="brandonmburroughs"),
#  NamedUser(login="bsun94"),
#  NamedUser(login="cswarth"),
#  NamedUser(login="DanielFEvans"),
#  NamedUser(login="dhirschfeld"),
#  NamedUser(login="dwhu"),
#  NamedUser(login="dwillmer"),
#  NamedUser(login="devin-petersohn"),
#  NamedUser(login="deniederhut"),
#  NamedUser(login="douglatornell"),
#  NamedUser(login="EricChea"),
#  NamedUser(login="fvia"),
#  NamedUser(login="gabriellm1"),
#  NamedUser(login="GGordonGordon"),
#  NamedUser(login="glemaitre"),
#  NamedUser(login="gpoulin"),
#  NamedUser(login="hammadmashkoor"),
#  NamedUser(login="wuhaochen"),
#  NamedUser(login="hvardhan20"),
#  NamedUser(login="hwalinga"),
#  NamedUser(login="huguesv"),
#  NamedUser(login="ijmbarr"),
#  NamedUser(login="Iqrar99"),
#  NamedUser(login="ivirshup"),
#  NamedUser(login="dukebody"),
#  NamedUser(login="ivannz"),
#  NamedUser(login="jackzyliu"),
#  NamedUser(login="jakevdp"),
#  NamedUser(login="jamescobonkerr"),
#  NamedUser(login="jdrudolph"),
#  NamedUser(login="Seuss27"),
#  NamedUser(login="jjlkant"),
#  NamedUser(login="JesperDramsch"),
#  NamedUser(login="joelostblom"),
#  NamedUser(login="Joeperdefloep"),
#  NamedUser(login="thejohnfreeman"),
#  NamedUser(login="josibake"),
#  NamedUser(login="jsignell"),
#  NamedUser(login="justinessert"),
#  NamedUser(login="kamilt5"),
#  NamedUser(login="karmel"),
#  NamedUser(login="keshavramaswamy")]
